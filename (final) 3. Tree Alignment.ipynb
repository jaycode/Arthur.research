# %% [markdown]
# # Tree Alignment
#
# As shown in [1], prior to detecting data fields we need to identify aligned regions across pages that look like potential data values. The paper uses DEPTA [2], but we are unsure if this is usable for PDF document too so let's explore it here.

# %% [markdown]
# ## 1. Load pdf and build a tag tree out of it.

# %%
# Tree with defaultdict
# https://gist.github.com/hrldcpr/2012250 but implemented by
# extending a dict object:
# http://stackoverflow.com/questions/6780952/how-to-change-behavior-of-dict-for-an-instance
class Tree(dict):
    """Implementation of perl's autovivification feature."""
    def __missing__(self, key):
        value = self[key] = type(self)()
        return value

test = Tree()
test['left']['value'] = 'leftval'
test['right']['value'] = 'rightval'
test['right']['right1']['value'] = 'testval'
print(test)
# Out:
# {'right': {'right1': {'value': 'testval'}, 'value': 'rightval'}, 'left': {'value': 'leftval'}}

# %%
import os, sys, inspect
base_path = os.path.realpath(
    os.path.abspath(
        os.path.join(
            os.path.split(
                inspect.getfile(
                    inspect.currentframe()
                )
            )[0],
            '..'
        )
    )
)
sys.path.append(base_path)

class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html).decode('utf-8')

from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.layout import LAParams
from pdfminer.converter import PDFConverter
from pdfminer.pdfpage import PDFPage

from pdfminer.layout import LTPage, LTContainer, LTAnno
from pdfminer.layout import LTImage, LTChar
from pdfminer.layout import LTTextBox, LTTextLine

from pdfminer.image import ImageWriter

try:
    from cStringIO import StringIO
except ImportError:
    from StringIO import StringIO
    
table = ListTable()
table.append([
    'type',
    'text',
    'x',
    'x1',
    'y',
    'y1',
    'page',
    'textbox_id',
    'textline_id'
])
tree = Tree()
types = set()
last_type = ''
class CustomPDFConverter(PDFConverter):
    def __init__(self, rsrcmgr, outfp, codec='utf-8', pageno=1, laparams=None,
                 showpageno=False, imagewriter=None):
        PDFConverter.__init__(self, rsrcmgr, outfp, codec=codec, pageno=pageno, laparams=laparams)
        self.showpageno = showpageno
        self.imagewriter = imagewriter
        self.current_total_height = 0
        return

    def write(self, message):
        self.outfp.write(message)

    def receive_layout(self, ltpage):
        """Stuff to do when layout received.

        Inherited from :class:`pdfminer.converter.PDFConverter`.

        Args:
            ltpage: :class:`pdfminer.layout.LTPage` object.
        """
        def render(item, page, page_width, current_total_height):
            """What to do when rendering certain :class:`pdfminer.layout.LT.*` objects.
            
            item.bbox has a set of (x0, y0, x1, y1)
            which we will store as part of our features.

            Important notes on features:
            - In pdf, (0,0) coordinate is positioned at bottom left, and each page has its own
              coordinates. To make it easier for learning and users to label, we combine all the
              pages into one huge, continuous plane, with position (0,0) on top left. This way
              users don't have to specify page number to create blocks, and learner can learn contents
              that span across multiple pages i.e. large paragraph of texts.

            Facts about LTTextBox:
            - It contains list of texts contained in LTTextLine... object,
              instead of single characters. Values of texts can be gathered with
              object.current_value. LTTextLine... contains LTChar.
            - LTTextLineHorizontal, LTTextLineVertical, or any child of LTTextBox does
              not have index, but we create our own index on the go (textline_id), so later
              we can trace back which LTText does an LTChar belong to.
            - LTTextBox does not seem to contain another LTTextBox, nor does it
              contain characters directly (at least in the examples so far).
            - Index can be gained from property `index` e.g. `item.index` (we will
              think about how to get this element from index later).

            Facts about LTImage:
            - object.srcsize are different from width and height calculated from bbox.
            - Belongs to no textbox.
            """
            global last_type
            if isinstance(item, LTPage):
                page = ltpage.pageid             
            if isinstance(item, LTContainer):
                for child in item:
                    render(child, page, page_width, current_total_height)
            if isinstance(item, LTTextBox):
                table.append([item.__class__.__name__])
                for textline_id, textline in enumerate(item):
                    element = textline
                    text = element.get_text().encode(self.codec, 'ignore')
                    tree[page][item.index][textline_id]['value'] = text
                    table.append([
                        element.__class__.__name__,
                        text,
                        element.bbox[0],
                        element.bbox[1],
                        element.bbox[2],
                        element.bbox[3],
                        page,
                        item.index,
                        textline_id
                    ])
            else:
                if not (isinstance(item, LTTextLine) or isinstance(item, LTChar)) and item.__class__.__name__ != last_type:
                    table.append([item.__class__.__name__])
            if isinstance(item, LTAnno):
                table.append(['-', item.get_text().encode(self.codec, 'ignore')])
            last_type = item.__class__.__name__


        self.current_total_height += ltpage.height
        render(ltpage, ltpage.pageid, ltpage.width, self.current_total_height)
        return

# %%
outfp = sys.stdout
pagenos = set()
pdf_path = 'pdfs/final/test.pdf'
f = open(pdf_path, 'rb')
text = f.read()

rsrcmgr = PDFResourceManager(caching=True)
codec = 'utf-8'
# imagewriter = ImageWriter('images')

laparams = LAParams()
device = CustomPDFConverter(rsrcmgr, outfp, codec=codec, laparams=laparams)
interpreter = PDFPageInterpreter(rsrcmgr, device)
interpreter.debug = False

pagenos = set()
text_io = StringIO(text)

for page in PDFPage.get_pages(text_io, pagenos):
    interpreter.process_page(page)
device.close()
print("types:", types)
table
# Out:
# ('types:', set([]))
# [['type', 'text', 'x', 'x1', 'y', 'y1', 'page', 'textbox_id', 'textline_id'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   585.36,
#   757.9702199999999,
#   588.54744,
#   777.44436,
#   1,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina Pipeline Corporation \n',
#   171.36,
#   636.15822,
#   481.701492,
#   672.9458999999999,
#   1,
#   1,
#   0],
#  ['LTTextLineHorizontal',
#   'Pipeline Failures \n',
#   171.36,
#   606.3331800000001,
#   346.7198040000001,
#   643.12086,
#   1,
#   1,
#   1],
#  ['LTTextLineHorizontal',
#   'Licence No. 2349, Line No. 10 \n',
#   171.36,
#   576.5081400000001,
#   475.89236400000004,
#   613.29582,
#   1,
#   1,
#   2],
#  ['LTTextLineHorizontal',
#   'July 20 and August 15, 2011 \n',
#   171.36,
#   546.6311400000002,
#   461.7306659999999,
#   583.4188200000001,
#   1,
#   1,
#   3],
#  ['LTTextLineHorizontal',
#   ' \n',
#   171.36,
#   526.0319999999999,
#   175.86,
#   549.684,
#   1,
#   1,
#   4],
#  ['LTTextLineHorizontal',
#   'ERCB Investigation Report  \n',
#   171.36,
#   505.29599999999994,
#   368.15579999999994,
#   530.7839999999999,
#   1,
#   1,
#   5],
#  ['LTTextLineHorizontal',
#   ' \n',
#   171.36,
#   484.6499999999999,
#   175.46400000000003,
#   510.1379999999999,
#   1,
#   1,
#   6],
#  ['LTTextLineHorizontal',
#   'February 26, 2013 \n',
#   171.36,
#   464.0039999999999,
#   300.1626,
#   489.4919999999999,
#   1,
#   1,
#   7],
#  ['LTTextLineHorizontal', ' \n', 171.36, 450.348, 174.36, 466.116, 1, 1, 8],
#  ['LTTextLineHorizontal', ' \n', 171.36, 436.428, 174.36, 452.424, 1, 1, 9],
#  ['LTTextLineHorizontal',
#   ' \n',
#   171.36,
#   422.748,
#   174.36,
#   438.51599999999996,
#   1,
#   1,
#   10],
#  ['LTTextLineHorizontal',
#   ' \n',
#   171.36,
#   413.57622,
#   173.17944,
#   424.8759,
#   1,
#   1,
#   11],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', ' \n', 399.0, 372.048, 402.0, 388.044, 1, 2, 0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   171.36,
#   18.141,
#   173.412,
#   30.884999999999998,
#   1,
#   3,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', ' \n', 72.0, 399.648, 75.0, 415.644, 1, 4, 0],
#  ['LTTextLineHorizontal', ' \n', 72.0, 385.848, 75.0, 401.844, 1, 4, 1],
#  ['LTTextLineHorizontal', ' \n', 72.0, 372.048, 75.0, 388.044, 1, 4, 2],
#  ['LTTextLineHorizontal', ' \n', 72.0, 358.308, 75.0, 374.304, 1, 4, 3],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   344.508,
#   75.0,
#   360.50399999999996,
#   1,
#   4,
#   4],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   330.70799999999997,
#   75.0,
#   346.70399999999995,
#   1,
#   4,
#   5],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   316.90799999999996,
#   75.0,
#   332.90399999999994,
#   1,
#   4,
#   6],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   303.10799999999995,
#   75.0,
#   319.1039999999999,
#   1,
#   4,
#   7],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   289.30799999999994,
#   75.0,
#   305.3039999999999,
#   1,
#   4,
#   8],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   275.5079999999999,
#   75.0,
#   291.5039999999999,
#   1,
#   4,
#   9],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   261.7079999999999,
#   75.0,
#   277.7039999999999,
#   1,
#   4,
#   10],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   247.90799999999987,
#   75.0,
#   263.9039999999999,
#   1,
#   4,
#   11],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   234.10799999999986,
#   75.0,
#   250.10399999999987,
#   1,
#   4,
#   12],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   220.30799999999985,
#   75.0,
#   236.30399999999986,
#   1,
#   4,
#   13],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   206.50799999999984,
#   75.0,
#   222.50399999999985,
#   1,
#   4,
#   14],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   192.70799999999983,
#   75.0,
#   208.70399999999984,
#   1,
#   4,
#   15],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   178.90799999999982,
#   75.0,
#   194.90399999999983,
#   1,
#   4,
#   16],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   165.1079999999998,
#   75.0,
#   181.10399999999981,
#   1,
#   4,
#   17],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   151.3079999999998,
#   75.0,
#   167.3039999999998,
#   1,
#   4,
#   18],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   137.50799999999978,
#   75.0,
#   153.5039999999998,
#   1,
#   4,
#   19],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   123.7079999999998,
#   75.0,
#   139.7039999999998,
#   1,
#   4,
#   20],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   109.9079999999998,
#   75.0,
#   125.9039999999998,
#   1,
#   4,
#   21],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   96.1079999999998,
#   75.0,
#   112.1039999999998,
#   1,
#   4,
#   22],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   82.30799999999981,
#   75.0,
#   98.3039999999998,
#   1,
#   4,
#   23],
#  ['LTImage'],
#  ['LTFigure'],
#  ['LTImage'],
#  ['LTFigure'],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   722.1983200000001,
#   77.92344,
#   758.986,
#   2,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', ' \n', 72.0, 686.388, 75.0, 702.384, 2, 1, 0],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   672.5880000000001,
#   75.0,
#   688.5840000000001,
#   2,
#   1,
#   1],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   658.7880000000001,
#   75.0,
#   674.7840000000001,
#   2,
#   1,
#   2],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   644.9880000000002,
#   75.0,
#   660.9840000000002,
#   2,
#   1,
#   3],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   631.2480000000002,
#   75.0,
#   647.2440000000001,
#   2,
#   1,
#   4],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   617.4480000000002,
#   75.0,
#   633.4440000000002,
#   2,
#   1,
#   5],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   603.6480000000003,
#   75.0,
#   619.6440000000002,
#   2,
#   1,
#   6],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   589.8480000000003,
#   75.0,
#   605.8440000000003,
#   2,
#   1,
#   7],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   576.0480000000003,
#   75.0,
#   592.0440000000003,
#   2,
#   1,
#   8],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   562.2480000000004,
#   75.0,
#   578.2440000000004,
#   2,
#   1,
#   9],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   548.4480000000004,
#   75.0,
#   564.4440000000004,
#   2,
#   1,
#   10],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   534.6480000000005,
#   75.0,
#   550.6440000000005,
#   2,
#   1,
#   11],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   520.8480000000005,
#   75.0,
#   536.8440000000005,
#   2,
#   1,
#   12],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   507.0480000000005,
#   75.0,
#   523.0440000000006,
#   2,
#   1,
#   13],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   493.2480000000005,
#   75.0,
#   509.2440000000005,
#   2,
#   1,
#   14],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   479.4480000000005,
#   75.0,
#   495.44400000000047,
#   2,
#   1,
#   15],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   465.6480000000005,
#   75.0,
#   481.64400000000046,
#   2,
#   1,
#   16],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   451.84800000000047,
#   75.0,
#   467.84400000000045,
#   2,
#   1,
#   17],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   438.04800000000046,
#   75.0,
#   454.04400000000044,
#   2,
#   1,
#   18],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   424.24800000000045,
#   75.0,
#   440.2440000000004,
#   2,
#   1,
#   19],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   410.44800000000043,
#   75.0,
#   426.4440000000004,
#   2,
#   1,
#   20],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   396.6480000000004,
#   75.0,
#   412.6440000000004,
#   2,
#   1,
#   21],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   382.8480000000004,
#   75.0,
#   398.8440000000004,
#   2,
#   1,
#   22],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   369.0480000000004,
#   75.0,
#   385.0440000000004,
#   2,
#   1,
#   23],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   355.2480000000004,
#   75.0,
#   371.24400000000037,
#   2,
#   1,
#   24],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   341.4480000000004,
#   75.0,
#   357.44400000000036,
#   2,
#   1,
#   25],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   327.64800000000037,
#   75.0,
#   343.64400000000035,
#   2,
#   1,
#   26],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   313.84800000000035,
#   75.0,
#   329.84400000000034,
#   2,
#   1,
#   27],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   300.04800000000034,
#   75.0,
#   316.0440000000003,
#   2,
#   1,
#   28],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   286.24800000000033,
#   75.0,
#   302.2440000000003,
#   2,
#   1,
#   29],
#  ['LTTextLineHorizontal',
#   'ENERGY RESOURCES CONSERVATION BOARD \n',
#   72.0,
#   273.62841999999995,
#   326.7469800000002,
#   288.26475999999997,
#   2,
#   1,
#   30],
#  ['LTTextLineHorizontal',
#   'ERCB Investigation Report: Pembina Pipeline Corporation, Pipeline Failures, July 20 and  \n',
#   72.0,
#   261.03435999999994,
#   474.1567739999995,
#   275.46207999999996,
#   2,
#   1,
#   31],
#  ['LTTextLineHorizontal',
#   'August 15, 2011 \n',
#   72.0,
#   248.44029999999995,
#   147.82239,
#   262.86801999999994,
#   2,
#   1,
#   32],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   235.78035999999994,
#   74.745,
#   250.20807999999994,
#   2,
#   1,
#   33],
#  ['LTTextLineHorizontal',
#   'February 26, 2013 \n',
#   72.0,
#   223.12041999999994,
#   155.808144,
#   237.54813999999993,
#   2,
#   1,
#   34],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   210.46047999999993,
#   74.745,
#   224.88819999999993,
#   2,
#   1,
#   35],
#  ['LTTextLineHorizontal',
#   'Published by \n',
#   72.0,
#   197.80053999999993,
#   131.88272400000002,
#   212.22825999999992,
#   2,
#   1,
#   36],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   185.14059999999992,
#   74.745,
#   199.56831999999991,
#   2,
#   1,
#   37],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   172.5465399999999,
#   74.745,
#   186.9742599999999,
#   2,
#   1,
#   38],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   159.8865999999999,
#   74.745,
#   174.3143199999999,
#   2,
#   1,
#   39],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   147.2266599999999,
#   74.745,
#   161.6543799999999,
#   2,
#   1,
#   40],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   134.5667199999999,
#   74.745,
#   148.99443999999988,
#   2,
#   1,
#   41],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   121.90677999999988,
#   74.745,
#   136.33449999999988,
#   2,
#   1,
#   42],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   109.31271999999989,
#   74.745,
#   123.74043999999988,
#   2,
#   1,
#   43],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   96.65277999999988,
#   74.745,
#   111.08049999999987,
#   2,
#   1,
#   44],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   83.99283999999987,
#   74.745,
#   98.42055999999987,
#   2,
#   1,
#   45],
#  ['LTTextLineHorizontal',
#   '  Website: www.ercb.ca \n',
#   71.99999999999997,
#   71.30848,
#   192.524838,
#   85.76061999999986,
#   2,
#   1,
#   46],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Energy Resources Conservation Board  \n',
#   90.000612,
#   172.5465399999999,
#   266.2691400000001,
#   186.9742599999999,
#   2,
#   2,
#   0],
#  ['LTTextLineHorizontal',
#   'Suite 1000, 250 \xe2\x80\x93 5 Street SW \n',
#   90.000612,
#   159.8865999999999,
#   226.37440800000002,
#   174.3143199999999,
#   2,
#   2,
#   1],
#  ['LTTextLineHorizontal',
#   'Calgary, Alberta \n',
#   89.999514,
#   147.2266599999999,
#   166.01734799999997,
#   161.6543799999999,
#   2,
#   2,
#   2],
#  ['LTTextLineHorizontal',
#   'T2P 0R4 \n',
#   89.999514,
#   134.5667199999999,
#   132.229692,
#   148.99443999999988,
#   2,
#   2,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Telephone: 403-297-8311 \n',
#   89.999514,
#   109.31271999999989,
#   207.32630399999996,
#   123.74043999999988,
#   2,
#   3,
#   0],
#  ['LTTextLineHorizontal',
#   'Toll free: 1-855-297-8311 \n',
#   90.00171,
#   96.65277999999988,
#   208.276074,
#   111.08049999999987,
#   2,
#   3,
#   1],
#  ['LTTextLineHorizontal',
#   'E-mail: infoservices@ercb.ca  \n',
#   89.999514,
#   83.99283999999987,
#   225.88909199999998,
#   98.42055999999987,
#   2,
#   3,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   18.141,
#   74.052,
#   30.884999999999998,
#   2,
#   4,
#   0],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', ' \n', 72.0, 761.42322, 74.50344, 776.9709, 3, 0, 0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Contents \n',
#   72.0,
#   703.91022,
#   124.93666800000001,
#   723.7059,
#   3,
#   1,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', '1 \n', 90.0, 680.208, 98.52, 695.976, 3, 2, 0],
#  ['LTTextLineHorizontal',
#   'Incident Description.........................................................................................................................1 \n',
#   108.0,
#   680.208,
#   542.52,
#   695.976,
#   3,
#   2,
#   1],
#  ['LTTextLineHorizontal',
#   '2  Pembina\xe2\x80\x99s Pipeline Monitoring and Maintenance...........................................................................3 \n',
#   90.0,
#   662.028,
#   542.52,
#   677.796,
#   3,
#   2,
#   2],
#  ['LTTextLineHorizontal',
#   '3  Root Cause Analysis........................................................................................................................3 \n',
#   90.0,
#   643.9081,
#   542.52,
#   659.6761,
#   3,
#   2,
#   3],
#  ['LTTextLineHorizontal',
#   '4 \n',
#   90.0,
#   625.7280000000001,
#   98.52,
#   641.4960000000001,
#   3,
#   2,
#   4],
#  ['LTTextLineHorizontal',
#   'Investigation Findings......................................................................................................................5 \n',
#   108.0,
#   625.7280000000001,
#   542.52,
#   641.4960000000001,
#   3,
#   2,
#   5],
#  ['LTTextLineHorizontal',
#   '5  Post-Incident Assessment ................................................................................................................7 \n',
#   90.0,
#   607.6080000000001,
#   542.52,
#   623.3760000000001,
#   3,
#   2,
#   6],
#  ['LTTextLineHorizontal',
#   '6  ERCB-Directed Actions...................................................................................................................7 \n',
#   90.0,
#   589.428,
#   542.52,
#   605.196,
#   3,
#   2,
#   7],
#  ['LTTextLineHorizontal',
#   '7  ERCB Follow-up .............................................................................................................................8 \n',
#   90.0,
#   571.308,
#   542.52,
#   587.076,
#   3,
#   2,
#   8],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal', ' \n', 72.0, 544.31022, 75.18744, 564.1059, 3, 3, 0],
#  ['LTTextLineHorizontal', ' \n', 72.0, 519.708, 75.0, 535.476, 3, 3, 1],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   505.90799999999996,
#   75.0,
#   521.6759999999999,
#   3,
#   3,
#   2],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   492.10799999999995,
#   75.0,
#   507.8759999999999,
#   3,
#   3,
#   3],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   478.30799999999994,
#   75.0,
#   494.0759999999999,
#   3,
#   3,
#   4],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   464.5079999999999,
#   75.0,
#   480.2759999999999,
#   3,
#   3,
#   5],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   450.7079999999999,
#   75.0,
#   466.4759999999999,
#   3,
#   3,
#   6],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   364.5,
#   464.5079999999999,
#   367.5,
#   480.2759999999999,
#   3,
#   4,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'ERCB Investigation Report: Pembina Pipeline Corporation, Pipeline Failures, July 20 and August 15, 2011 (February 26, 2013)    \xe2\x80\xa2    i \n',
#   80.1,
#   18.141,
#   542.0502,
#   30.884999999999998,
#   3,
#   5,
#   0],
#  ['LTRect'],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   764.9963200000001,
#   73.81944,
#   776.296,
#   5,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '1 \n',
#   72.0,
#   696.38322,
#   80.09226000000001,
#   711.9309000000001,
#   5,
#   1,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Incident Description  \n',
#   89.99622000000001,
#   696.38322,
#   182.80467000000002,
#   711.9309000000001,
#   5,
#   2,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'First Failure (July 20, 2011) \n',
#   125.99964,
#   672.75426,
#   255.50983800000006,
#   687.35766,
#   5,
#   3,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'At 7:02 a.m.1 on July 20, 2011, the Pembina Pipeline Corporation (Pembina) contacted the \n',
#   125.99964,
#   649.2241200000001,
#   528.8235840000001,
#   664.28806,
#   5,
#   4,
#   0],
#  ['LTTextLineHorizontal',
#   'ERCB St. Albert Field Centre (SAFC) to report a pipeline failure and a sweet crude oil \n',
#   126.00252,
#   636.56838,
#   511.3851479999993,
#   650.9961000000001,
#   5,
#   4,
#   1],
#  ['LTTextLineHorizontal',
#   'release from the Moosehorn gathering pipeline in the Swan Hills area. The failure site (Legal \n',
#   126.00252,
#   623.90844,
#   538.3048140000001,
#   638.3361600000001,
#   5,
#   4,
#   2],
#  ['LTTextLineHorizontal',
#   'Subdivision [LSD] 11, Section 7, Township 67, Range 9, West of the 5th Meridian) was \n',
#   126.00252,
#   611.2485,
#   517.3582680000003,
#   625.6762200000001,
#   5,
#   4,
#   3],
#  ['LTTextLineHorizontal',
#   'about 7.5 kilometres north, northeast of the Swan Hills town site.  \n',
#   126.00252,
#   598.58856,
#   418.34721600000006,
#   613.01628,
#   5,
#   4,
#   4],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'In the days leading up to the release, Pembina\xe2\x80\x99s Edmonton Control Centre (ECC) had been \n',
#   126.00251999999998,
#   574.94862,
#   529.3440359999998,
#   589.37634,
#   5,
#   5,
#   0],
#  ['LTTextLineHorizontal',
#   'addressing various operating anomalies identified by Pembina\xe2\x80\x99s supervisory control and data \n',
#   126.00251999999995,
#   562.35456,
#   538.1346239999997,
#   576.78228,
#   5,
#   5,
#   1],
#  ['LTTextLineHorizontal',
#   'acquisition (SCADA) system. These anomalies were initially triggered by the remnants of a \n',
#   126.00251999999995,
#   549.69462,
#   532.8817920000001,
#   564.12234,
#   5,
#   5,
#   2],
#  ['LTTextLineHorizontal',
#   'nitrogen purge on July 9, 2011, on a segment of the pipeline that resulted in a measured \n',
#   126.00251999999995,
#   537.03468,
#   514.1828519999999,
#   551.4624,
#   5,
#   5,
#   3],
#  ['LTTextLineHorizontal',
#   'segment volume imbalance. On July 19, 2011, at 7:42 a.m. the ECC foreman reviewed the \n',
#   126.00251999999995,
#   524.37474,
#   526.7275020000003,
#   538.80246,
#   5,
#   5,
#   4],
#  ['LTTextLineHorizontal',
#   '24-hour segment volume imbalance, and based on continuing segment volume imbalance, the \n',
#   126.00251999999995,
#   511.7147999999999,
#   541.453878,
#   526.14252,
#   5,
#   5,
#   5],
#  ['LTTextLineHorizontal',
#   'foreman remotely shut down the pipeline. After the pipeline was shut down, Pembina began a \n',
#   126.00251999999998,
#   499.1207399999999,
#   541.629558,
#   513.54846,
#   5,
#   5,
#   6],
#  ['LTTextLineHorizontal',
#   'field verification process. However, during the field verification process, the release location \n',
#   126.00252,
#   486.4607999999999,
#   537.0388199999994,
#   500.8885199999999,
#   5,
#   5,
#   7],
#  ['LTTextLineHorizontal',
#   'was identified by a third party (a Devon Canada Inc. [Devon] representative) at about 6:30 \n',
#   126.00252,
#   473.8008599999999,
#   527.544414,
#   488.2285799999999,
#   5,
#   5,
#   8],
#  ['LTTextLineHorizontal',
#   'p.m. on July 19, 2011. Pembina reported the failure and the release location to the SAFC at \n',
#   126.00252,
#   461.1409199999999,
#   530.1587519999998,
#   475.5686399999999,
#   5,
#   5,
#   9],
#  ['LTTextLineHorizontal',
#   '7:02 a.m. on July 20, 2011, almost 24 hours after Pembina shut down the pipeline and over \n',
#   126.00251999999998,
#   448.4809799999999,
#   529.5702239999999,
#   462.9086999999999,
#   5,
#   5,
#   10],
#  ['LTTextLineHorizontal',
#   '12 hours following identification of the failure location by Devon. \n',
#   126.00251999999995,
#   435.7551599999999,
#   420.2851860000001,
#   450.4573799999999,
#   5,
#   5,
#   11],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The SAFC designated this as a level-1 emergency using the ERCB Assessment Matrix for \n',
#   126.00251999999995,
#   412.1810999999999,
#   525.5669159999999,
#   426.6088199999999,
#   5,
#   6,
#   0],
#  ['LTTextLineHorizontal',
#   'Classifying Incidents in ERCB Directive 071: Emergency Preparedness and Response \n',
#   126.00251999999992,
#   399.5211599999999,
#   510.18613200000004,
#   414.1245599999999,
#   5,
#   6,
#   1],
#  ['LTTextLineHorizontal',
#   'Requirements for the Petroleum Industry. On release notification, the SAFC activated an \n',
#   125.9915399999999,
#   386.9270999999999,
#   519.5268179999997,
#   401.5304999999999,
#   5,
#   6,
#   2],
#  ['LTTextLineHorizontal',
#   'emergency operations centre (EOC) at the SAFC to coordinate the ERCB\xe2\x80\x99s response. \n',
#   125.99153999999993,
#   374.2012799999999,
#   504.4567679999999,
#   388.6289999999999,
#   5,
#   6,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The failure resulted in crude oil migrating overland from the failure location down the \n',
#   125.99153999999996,
#   350.6272199999999,
#   507.8737440000002,
#   365.05493999999993,
#   5,
#   7,
#   0],
#  ['LTTextLineHorizontal',
#   'pipeline right-of-way surface into a mixed forested area next to the right-of-way and into an \n',
#   125.99153999999996,
#   337.9672799999999,
#   533.1628800000001,
#   352.3949999999999,
#   5,
#   7,
#   1],
#  ['LTTextLineHorizontal',
#   'unnamed but actively flowing creek. About 3.6 km of the creek and creek bank were affected \n',
#   125.99153999999999,
#   325.3073399999999,
#   539.6037480000001,
#   339.7350599999999,
#   5,
#   7,
#   2],
#  ['LTTextLineHorizontal',
#   'by the release.    \n',
#   125.99153999999999,
#   312.5815199999999,
#   200.278926,
#   327.0092399999999,
#   5,
#   7,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Once Pembina confirmed the failure, it activated its corporate emergency response plan \n',
#   125.99153999999999,
#   289.0074599999999,
#   514.2026160000003,
#   303.43517999999995,
#   5,
#   8,
#   0],
#  ['LTTextLineHorizontal',
#   '(ERP), established a response operations centre, and dispatched emergency response \n',
#   125.99153999999999,
#   276.3475199999999,
#   501.1298280000001,
#   290.77523999999994,
#   5,
#   8,
#   1],
#  ['LTTextLineHorizontal',
#   'equipment to the release site. On July 19, 2011, at about 8:00 p.m., Pembina installed a \n',
#   125.99153999999996,
#   263.6875799999999,
#   512.1625320000004,
#   278.11529999999993,
#   5,
#   8,
#   2],
#  ['LTTextLineHorizontal',
#   'containment weir and built earthen berms to minimize any further environmental effects. To \n',
#   125.99153999999996,
#   251.09351999999993,
#   534.6320040000003,
#   265.5212399999999,
#   5,
#   8,
#   3],
#  ['LTTextLineHorizontal',
#   'mitigate further seepage from the failed pipeline, Pembina started evacuating the crude oil \n',
#   125.99153999999999,
#   238.43357999999992,
#   525.5306820000002,
#   252.86129999999991,
#   5,
#   8,
#   4],
#  ['LTTextLineHorizontal',
#   'from the pipeline on July 20, 2011, at 10:30 p.m. and seepage was stopped within 30 minutes. \n',
#   125.99153999999999,
#   225.70775999999992,
#   542.1335400000004,
#   240.13547999999992,
#   5,
#   8,
#   5],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Within about 48 hours from the discovery of the release, Pembina staff and third-party \n',
#   125.99153999999999,
#   202.13369999999992,
#   509.4109440000002,
#   216.5614199999999,
#   5,
#   9,
#   0],
#  ['LTTextLineHorizontal',
#   'contractors established and executed containment and recovery operations that included a \n',
#   125.99153999999999,
#   189.4737599999999,
#   522.8131320000001,
#   203.9014799999999,
#   5,
#   9,
#   1],
#  ['LTTextLineHorizontal',
#   'number of monitoring and control points (oil recovery and sampling locations) downstream \n',
#   125.99154000000001,
#   176.8138199999999,
#   531.6816779999999,
#   191.2415399999999,
#   5,
#   9,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '                                                      \n',
#   71.99190000000004,
#   141.10799999999998,
#   219.0,
#   156.87599999999998,
#   5,
#   10,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '\xef\x80\xaa  This report is accompanied by supporting documents. These documents are available from the webpage for this \n',
#   72.0,
#   118.13568,
#   529.1630339999998,
#   131.31888,
#   5,
#   11,
#   0],
#  ['LTTextLineHorizontal',
#   'investigation report on the ERCB website, www.ercb.ca. For ease of reference, each document has been given a \n',
#   80.64078,
#   106.6728,
#   531.10992,
#   119.83908,
#   5,
#   11,
#   1],
#  ['LTTextLineHorizontal',
#   'number, which is provided in a footnote when the document is cited (e.g., DOC01, DOC02, etc.). \n',
#   80.64078,
#   95.1498,
#   472.82742599999995,
#   108.31906000000001,
#   5,
#   11,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '1  ERCB records indicate that the initial incident report was received at 7:02 a.m., while Pembina\xe2\x80\x99s records indicate \n',
#   72.0,
#   83.63568,
#   536.58084,
#   97.41504,
#   5,
#   12,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '6:50 a.m. The ERCB will use its own time logs for this report. \n',
#   80.63076000000001,
#   72.1728,
#   332.32314,
#   85.33908,
#   5,
#   13,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'ERCB Investigation Report: Pembina Pipeline Corporation, Pipeline Failures, July 20 and August 15, 2011 (February 26, 2013)    \xe2\x80\xa2    1 \n',
#   78.06,
#   20.301,
#   542.0495999999999,
#   33.045,
#   5,
#   14,
#   0],
#  ['LTRect'],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   764.9963200000001,
#   73.81944,
#   776.296,
#   6,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'of the initial creek entry. At 6:07 p.m. on July 24, 2011, the incident was called down2 by the \n',
#   126.0,
#   707.48832,
#   539.347224,
#   722.54796,
#   6,
#   1,
#   0],
#  ['LTTextLineHorizontal',
#   'ERCB and the ERCB EOC ceased operations. Once the monitoring program was initiated, \n',
#   125.99633999999998,
#   694.82838,
#   527.0243700000002,
#   709.2561000000001,
#   6,
#   1,
#   1],
#  ['LTTextLineHorizontal',
#   'discussions were held with Alberta Environment (now Environment and Sustainable \n',
#   125.99633999999998,
#   682.16844,
#   500.4648480000002,
#   696.59616,
#   6,
#   1,
#   2],
#  ['LTTextLineHorizontal',
#   'Resource Development [ESRD]) regarding the sampling and sample results throughout the \n',
#   125.99633999999998,
#   669.57438,
#   529.05018,
#   684.0021,
#   6,
#   1,
#   3],
#  ['LTTextLineHorizontal',
#   'incident; modifications were made as appropriate. As of the date of this report, monthly \n',
#   125.99633999999998,
#   656.91444,
#   514.657596,
#   671.34216,
#   6,
#   1,
#   4],
#  ['LTTextLineHorizontal',
#   'sampling of the creek water is being conducted by a Pembina contractor; no impacts have \n',
#   125.99633999999998,
#   644.2545,
#   523.4426940000005,
#   658.68222,
#   6,
#   1,
#   5],
#  ['LTTextLineHorizontal',
#   'been reported to ESRD. An affected area where excavation activities occurred due to \n',
#   125.99633999999998,
#   631.59456,
#   503.0209919999993,
#   646.02228,
#   6,
#   1,
#   6],
#  ['LTTextLineHorizontal',
#   'ineffective flushing operations has been backfilled and recontoured with the exception of a \n',
#   125.99633999999998,
#   618.93462,
#   528.40236,
#   633.36234,
#   6,
#   1,
#   7],
#  ['LTTextLineHorizontal',
#   'few localized areas. These areas will be risk managed in accordance with ESRD guidelines. \n',
#   125.99634,
#   606.27468,
#   532.249752,
#   620.7024,
#   6,
#   1,
#   8],
#  ['LTTextLineHorizontal',
#   'Reclamation of the spill area, including the entry point to the creek, has been mostly \n',
#   125.99634,
#   593.68062,
#   499.67758200000014,
#   608.10834,
#   6,
#   1,
#   9],
#  ['LTTextLineHorizontal',
#   'completed. Erosion barriers, coconut matting,3 and seeding with an approved seed mixture \n',
#   125.99634,
#   581.00832,
#   527.8947240000001,
#   596.06796,
#   6,
#   1,
#   10],
#  ['LTTextLineHorizontal',
#   'have taken place from the initial point of release up to and including the affected creek banks. \n',
#   125.99598000000003,
#   568.34838,
#   541.3957320000001,
#   582.7761,
#   6,
#   1,
#   11],
#  ['LTTextLineHorizontal',
#   'Salvaged organic cover has been spread and seedlings have been planted on areas where \n',
#   125.99598,
#   555.68844,
#   517.5493680000001,
#   570.11616,
#   6,
#   1,
#   12],
#  ['LTTextLineHorizontal',
#   'steeper gradients could cause erosion and slope instability. Further remediation and \n',
#   125.99598000000003,
#   543.0285,
#   495.6684240000002,
#   557.45622,
#   6,
#   1,
#   13],
#  ['LTTextLineHorizontal',
#   'monitoring will continue until the requirements of all other relevant regulatory agencies \n',
#   125.99598,
#   530.43444,
#   515.1271800000002,
#   544.86216,
#   6,
#   1,
#   14],
#  ['LTTextLineHorizontal',
#   '(ESRD and Environment Canada) are satisfied. \n',
#   125.99597999999997,
#   517.7745,
#   337.087578,
#   532.20222,
#   6,
#   1,
#   15],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The incident occurred on Crown land in a rural wooded area with no residences. The SAFC \n',
#   125.99597999999997,
#   494.0686799999999,
#   531.863994,
#   508.49639999999994,
#   6,
#   2,
#   0],
#  ['LTTextLineHorizontal',
#   'did not receive any public complaints relating to the incidents. The failures did receive media \n',
#   125.99597999999995,
#   481.4746199999999,
#   539.5302299999998,
#   495.9023399999999,
#   6,
#   2,
#   1],
#  ['LTTextLineHorizontal',
#   'attention, and both Pembina and the ERCB issued press releases relating to the incident. \n',
#   125.99597999999995,
#   468.7487999999999,
#   516.4656420000002,
#   483.1765199999999,
#   6,
#   2,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina initially estimated the release volume at about 200 cubic metres (m3). After a more \n',
#   125.99597999999997,
#   445.16832,
#   533.8801559999999,
#   460.22796,
#   6,
#   3,
#   0],
#  ['LTTextLineHorizontal',
#   'detailed evaluation, Pembina revised the release volume to between 130 m3 to 160 m3. \n',
#   126.00389999999993,
#   432.50831999999997,
#   508.605272,
#   447.56796,
#   6,
#   3,
#   1],
#  ['LTTextLineHorizontal',
#   'Pembina removed the failed pipeline section and sent it to an independent third party, Det \n',
#   126.00277999999997,
#   419.84837999999996,
#   523.8059840000001,
#   434.2761,
#   6,
#   3,
#   2],
#  ['LTTextLineHorizontal',
#   'Norske Veritas (DNV), to complete a failure mechanism and metallurgical analysis. DNV \n',
#   126.00277999999997,
#   407.18843999999996,
#   524.9127679999998,
#   421.61616,
#   6,
#   3,
#   3],
#  ['LTTextLineHorizontal',
#   'prepared a report dated September 27, 20114 (first DNV report), which Pembina provided to \n',
#   126.00277999999997,
#   394.58831999999995,
#   536.233416,
#   409.64796,
#   6,
#   3,
#   4],
#  ['LTTextLineHorizontal',
#   'the ERCB.   \n',
#   125.99645999999998,
#   381.86249999999995,
#   181.90881599999997,
#   396.29022,
#   6,
#   3,
#   5],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Second Failure (August 15, 2011) \n',
#   125.99645999999998,
#   358.15667999999994,
#   278.16608400000007,
#   372.76007999999996,
#   6,
#   4,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'At about 9:10 a.m. on August 15, 2011, Pembina reported a second pipeline failure about \n',
#   125.99645999999998,
#   334.58261999999996,
#   521.548764,
#   349.01034,
#   6,
#   5,
#   0],
#  ['LTTextLineHorizontal',
#   '1600 m from the location of the first failure. There is no way to determine the exact time the \n',
#   125.99645999999996,
#   321.98855999999995,
#   535.256196,
#   336.41628,
#   6,
#   5,
#   1],
#  ['LTTextLineHorizontal',
#   'failure occurred as the second failure was identified while the pipeline was not operational \n',
#   125.99645999999993,
#   309.32861999999994,
#   526.6753259999999,
#   323.75633999999997,
#   6,
#   5,
#   2],
#  ['LTTextLineHorizontal',
#   'and crews were at the first failure location. The second failure site was located at LSD 14-7-\n',
#   125.98547999999988,
#   296.66867999999994,
#   532.0138019999997,
#   311.09639999999996,
#   6,
#   5,
#   3],
#  ['LTTextLineHorizontal',
#   '67-9W5M, near the top of a small high area within the segment that had previously been \n',
#   125.98547999999988,
#   284.00873999999993,
#   518.52048,
#   298.43645999999995,
#   6,
#   5,
#   4],
#  ['LTTextLineHorizontal',
#   'drained to allow the repair of the first failure to proceed. Therefore, the release was limited to \n',
#   125.98547999999988,
#   271.3487999999999,
#   539.8809719999996,
#   285.77651999999995,
#   6,
#   5,
#   5],
#  ['LTTextLineHorizontal',
#   'a small volume of oil remaining in the pipeline at that location.   \n',
#   125.98547999999988,
#   258.6888599999999,
#   411.69605999999925,
#   273.11657999999994,
#   6,
#   5,
#   6],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The second release affected an area of about 4 x 70 m on the pipeline right-of-way and did \n',
#   125.98547999999988,
#   235.04891999999995,
#   527.2693439999999,
#   249.47663999999995,
#   6,
#   6,
#   0],
#  ['LTTextLineHorizontal',
#   'not migrate into the surrounding forest. Based on the size of the impacted area, the ERCB \n',
#   125.98547999999988,
#   222.45485999999994,
#   523.6876679999995,
#   236.88257999999993,
#   6,
#   6,
#   1],
#  ['LTTextLineHorizontal',
#   'accepted Pembina\xe2\x80\x99s reported release volume of less than 1 m3. Pembina\xe2\x80\x99s response and clean-\n',
#   125.98547999999988,
#   209.78832,
#   539.354088,
#   224.84796,
#   6,
#   6,
#   2],
#  ['LTTextLineHorizontal',
#   'up operations consisted of moving recovery equipment and crews from the first failure \n',
#   126.00540000000001,
#   197.12838,
#   509.984784,
#   211.5561,
#   6,
#   6,
#   3],
#  ['LTTextLineHorizontal',
#   'location to the second failure location when they became available.  \n',
#   126.00540000000001,
#   184.40256,
#   427.2373079999994,
#   198.83028,
#   6,
#   6,
#   4],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '                                                      \n',
#   72.00576000000001,
#   151.908,
#   219.0,
#   167.676,
#   6,
#   7,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '2  To downgrade an incident means to reduce the emergency level (e.g., from level-2 to level-1 or alert) based on the \n',
#   72.0,
#   129.65568,
#   540.8994600000002,
#   143.43504,
#   6,
#   8,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'changing incident elements. To call down an incident means the emergency phase of the incident is over.  \n',
#   80.64077999999999,
#   118.13268,
#   506.0438879999996,
#   131.29896,
#   6,
#   9,
#   0],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '3   Coconut matting consists of open weave, pure coconut mesh that offers durable surface erosion control. It is, \n',
#   72.0,
#   106.67578,
#   518.8098719999999,
#   120.45514000000001,
#   6,
#   10,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'therefore, recommended on sites where erosion forces are strong, climate is harsh, or plants are slow to establish. \n',
#   80.99999999999994,
#   95.15278,
#   535.942512,
#   108.31906000000001,
#   6,
#   11,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '4  Det Norske Veritas, Final Report \xe2\x80\x93 Metallurgical Analysis of Leak on the 8-Inch Diameter Moosehorn Oil \n',
#   72.0,
#   83.63568,
#   509.73726000000005,
#   97.41504,
#   6,
#   12,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pipeline, September 27, 2011 (DOC01). \n',
#   80.63075999999997,
#   72.1728,
#   244.55795999999995,
#   85.4994,
#   6,
#   13,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '2   \xe2\x80\xa2   ERCB Investigation Report: Pembina Pipeline Corporation, Pipeline Failures, July 20 and August 15, 2011 (February 26, 2013)  \n',
#   72.0,
#   20.301,
#   533.961,
#   33.045,
#   6,
#   14,
#   0],
#  ['LTRect'],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   764.9963200000001,
#   73.81944,
#   776.296,
#   7,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina removed the second failed pipeline section and also sent it to DNV for analysis. \n',
#   126.0,
#   707.48832,
#   520.717824,
#   721.9160400000001,
#   7,
#   1,
#   0],
#  ['LTTextLineHorizontal',
#   'DNV prepared a report dated November 1, 20115 (second DNV report), which Pembina \n',
#   126.0,
#   694.8283200000001,
#   516.37266,
#   709.88806,
#   7,
#   1,
#   1],
#  ['LTTextLineHorizontal',
#   'provided to the ERCB.    \n',
#   126.00072000000003,
#   682.1025000000001,
#   237.82543200000003,
#   696.5302200000001,
#   7,
#   1,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pipeline History \n',
#   126.00072000000003,
#   658.45158,
#   196.56918000000007,
#   673.99926,
#   7,
#   2,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The Moosehorn gathering pipeline, with an outside diameter of 219.1 millimetres (mm)  \n',
#   126.00072000000003,
#   634.9324200000001,
#   517.3454880000002,
#   649.3601400000001,
#   7,
#   3,
#   0],
#  ['LTTextLineHorizontal',
#   '(8 inches) and a wall thickness of 4.8 mm, is composed of carbon steel and externally coated \n',
#   126.00072000000003,
#   622.2724800000001,
#   536.984316,
#   636.7002000000001,
#   7,
#   3,
#   1],
#  ['LTTextLineHorizontal',
#   'with polyethylene tape and a fiberglass outer wrap. Pembina purchased this pipeline, \n',
#   126.00072000000006,
#   609.6125400000001,
#   501.6792240000002,
#   624.0402600000001,
#   7,
#   3,
#   2],
#  ['LTTextLineHorizontal',
#   'originally licensed in 1962, from Federated Pipe Lines Ltd. in 2000. \n',
#   126.00072000000009,
#   596.8867200000001,
#   428.5238760000002,
#   611.3144400000001,
#   7,
#   3,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The pipeline is part of the Pembina, Swan Hills gathering pipeline system, comprising 21 \n',
#   126.00072000000009,
#   573.31266,
#   521.9581860000006,
#   587.7403800000001,
#   7,
#   4,
#   0],
#  ['LTTextLineHorizontal',
#   'lateral gathering pipelines that transport sweet crude oil from various producing segments in \n',
#   126.00072000000009,
#   560.65272,
#   535.045248,
#   575.0804400000001,
#   7,
#   4,
#   1],
#  ['LTTextLineHorizontal',
#   'the Swan Hills area. \n',
#   126.00072000000006,
#   547.9269,
#   217.2620880000001,
#   562.3546200000001,
#   7,
#   4,
#   2],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '2  Pembina\xe2\x80\x99s Pipeline Monitoring and Maintenance \n',
#   72.00108000000006,
#   524.27598,
#   299.408958,
#   539.82366,
#   7,
#   5,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina has a pipeline integrity management program (IMP) that consists of a series of \n',
#   126.00072000000006,
#   500.70192,
#   514.994075999999,
#   515.15698,
#   7,
#   6,
#   0],
#  ['LTTextLineHorizontal',
#   'program manuals covering various aspects of pipeline integrity management. Collectively, \n',
#   126.00342,
#   488.13519999999994,
#   527.5277460000002,
#   502.56291999999996,
#   7,
#   6,
#   1],
#  ['LTTextLineHorizontal',
#   'these manuals assign responsibility and define the \xe2\x80\x9cwho, what, where, when, why, and how\xe2\x80\x9d \n',
#   126.00342,
#   475.47525999999993,
#   536.2359839999996,
#   489.90297999999996,
#   7,
#   6,
#   2],
#  ['LTTextLineHorizontal',
#   'to manage pipeline integrity. Pembina has confirmed that the program manuals describe \n',
#   126.00342,
#   462.81531999999993,
#   516.0108240000001,
#   477.24303999999995,
#   7,
#   6,
#   3],
#  ['LTTextLineHorizontal',
#   'inspection, monitoring, and mitigation activities to address the threats to the long-term \n',
#   126.00342,
#   450.1553799999999,
#   508.989114,
#   464.58309999999994,
#   7,
#   6,
#   4],
#  ['LTTextLineHorizontal',
#   'integrity of its pipelines. The program manuals address mechanical damage, mill defects, \n',
#   126.00342,
#   437.4954399999999,
#   520.9847640000002,
#   451.92315999999994,
#   7,
#   6,
#   5],
#  ['LTTextLineHorizontal',
#   'corrosion, stress corrosion cracking, coating damage, coating deterioration, unstable slopes, \n',
#   126.00342000000003,
#   424.9013799999999,
#   532.0130760000001,
#   439.3290999999999,
#   7,
#   6,
#   6],
#  ['LTTextLineHorizontal',
#   'and the presence of low-frequency electric resistance welded pipe.  \n',
#   126.00342000000006,
#   412.1755599999999,
#   423.81395999999967,
#   426.6032799999999,
#   7,
#   6,
#   7],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina uses SCADA technology on all its pipeline systems, enabling continuous electronic \n',
#   126.00342000000006,
#   388.60149999999993,
#   537.3757080000001,
#   403.02921999999995,
#   7,
#   7,
#   0],
#  ['LTTextLineHorizontal',
#   'monitoring and control of the pipeline systems from dedicated computer consoles located in \n',
#   126.00342000000006,
#   375.9415599999999,
#   533.8313640000001,
#   390.36927999999995,
#   7,
#   7,
#   1],
#  ['LTTextLineHorizontal',
#   'the ECC. The systems are monitored 24 hours per day, 365 days per year. The SCADA \n',
#   126.00342000000003,
#   363.2816199999999,
#   513.0001079999996,
#   377.70933999999994,
#   7,
#   7,
#   2],
#  ['LTTextLineHorizontal',
#   'system and associated leak detection software continuously monitor pipeline flow and \n',
#   126.00342000000003,
#   350.6216799999999,
#   507.68578800000057,
#   365.04939999999993,
#   7,
#   7,
#   3],
#  ['LTTextLineHorizontal',
#   'operating conditions. When SCADA alarms are triggered, ECC operators and shift foremen \n',
#   126.00342000000003,
#   337.9617399999999,
#   532.2842819999994,
#   352.38945999999993,
#   7,
#   7,
#   4],
#  ['LTTextLineHorizontal',
#   'implement prescribed protocol to investigate the alarm, and, initiate line shutdown \n',
#   126.00342000000003,
#   325.3676799999999,
#   491.644008,
#   339.7953999999999,
#   7,
#   7,
#   5],
#  ['LTTextLineHorizontal',
#   'procedures. Pembina routinely conducts leak tests whereby hydrocarbons are temporarily \n',
#   126.00342000000003,
#   312.7077399999999,
#   522.1420559999995,
#   327.1354599999999,
#   7,
#   7,
#   6],
#  ['LTTextLineHorizontal',
#   'diverted away from the pipeline into tanker trucks to test the SCADA system and ECC \n',
#   126.00342000000003,
#   300.0477999999999,
#   510.65917199999996,
#   314.4755199999999,
#   7,
#   7,
#   7],
#  ['LTTextLineHorizontal',
#   'operator performance. The last leak test occurred in September 2010, about one year prior to \n',
#   126.00342000000006,
#   287.3878599999999,
#   536.319432,
#   301.8155799999999,
#   7,
#   7,
#   8],
#  ['LTTextLineHorizontal',
#   'the first failure. \n',
#   126.00342000000006,
#   274.6620399999999,
#   196.86614400000008,
#   289.0897599999999,
#   7,
#   7,
#   9],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '3  Root Cause Analysis \n',
#   72.00378000000006,
#   251.01111999999992,
#   182.12110200000012,
#   266.5587999999999,
#   7,
#   8,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pembina retained DNV to perform a metallurgical analysis on the failed pipe. The objectives \n',
#   126.00342000000006,
#   227.42926,
#   537.4108439999999,
#   241.8647799999999,
#   7,
#   9,
#   0],
#  ['LTTextLineHorizontal',
#   'of the analyses were to determine the metallurgical cause of the failures and identify any \n',
#   125.99244000000002,
#   214.8352,
#   518.5384199999996,
#   229.26291999999998,
#   7,
#   9,
#   1],
#  ['LTTextLineHorizontal',
#   'contributing factors. For both failures, the DNV analysis included  \n',
#   125.99244000000002,
#   202.17525999999998,
#   421.04919600000005,
#   216.87748,
#   7,
#   9,
#   2],
#  ['LTTextLineHorizontal',
#   '\xef\x82\xb7  magnetic particle inspection,  \n',
#   126.0,
#   183.50842,
#   276.3353520000001,
#   197.93614,
#   7,
#   9,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '\xef\x82\xb7 \n',
#   126.0,
#   165.47238,
#   131.88126,
#   176.1576,
#   7,
#   10,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'examination and measurement of fracture surfaces of the cracks identified by the \n',
#   144.0,
#   164.84832,
#   502.60680000000013,
#   179.27604,
#   7,
#   11,
#   0],
#  ['LTTextLineHorizontal',
#   'magnetic particle inspection, examination of some of the fracture surfaces under a \n',
#   144.00000000000003,
#   152.18838,
#   507.7234800000002,
#   166.6161,
#   7,
#   11,
#   1],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '                                                      \n',
#   72.00414,
#   105.888,
#   219.0,
#   121.656,
#   7,
#   12,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '5  Det Norske Veritas, Final Report \xe2\x80\x93 Metallurgical Analysis of Leak on Eight-Inch Diameter Moosehorn Oil \n',
#   72.0,
#   83.63568,
#   511.6771320000001,
#   97.41504,
#   7,
#   13,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pipeline, November 1, 2011 (DOC02). \n',
#   80.63075999999997,
#   72.1728,
#   239.022912,
#   85.4994,
#   7,
#   14,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'ERCB Investigation Report: Pembina Pipeline Corporation, Pipeline Failures, July 20 and August 15, 2011 (February 26, 2013)   \xe2\x80\xa2   3 \n',
#   82.2,
#   20.301,
#   542.0541000000001,
#   33.045,
#   7,
#   15,
#   0],
#  ['LTRect'],
#  ['LTPage'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   ' \n',
#   72.0,
#   764.9963200000001,
#   73.81944,
#   776.296,
#   8,
#   0,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'scanning electron microscope to document the fracture morphology and to determine if \n',
#   144.0,
#   707.48832,
#   530.6804640000001,
#   721.9160400000001,
#   8,
#   1,
#   0],
#  ['LTTextLineHorizontal',
#   'there was any evidence of in-service growth by fatigue, and  \n',
#   144.0,
#   694.82838,
#   412.28531999999984,
#   709.2561000000001,
#   8,
#   1,
#   1],
#  ['LTAnno'],
#  ['-', ' '],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '\xef\x82\xb7  mechanical testing and chemical analysis of the samples removed from the pipe. \n',
#   126.0,
#   676.10832,
#   500.4470339999991,
#   690.5360400000001,
#   8,
#   2,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Both DNV reports identified transgranular, circumferentially aligned stress corrosion \n',
#   126.00378,
#   652.53426,
#   503.8244819999992,
#   666.96198,
#   8,
#   3,
#   0],
#  ['LTTextLineHorizontal',
#   'cracking (C-SCC)6 as the cause for pipe failure. The DNV reports concluded that the failures \n',
#   126.00378,
#   639.86842,
#   538.6261560000002,
#   654.92796,
#   8,
#   3,
#   1],
#  ['LTTextLineHorizontal',
#   'occurred at a colony of C-SCC. Several other C-SCC colonies were present on the pipe joints. \n',
#   125.99555999999995,
#   627.27436,
#   542.7173039999999,
#   641.70208,
#   8,
#   3,
#   2],
#  ['LTTextLineHorizontal',
#   'There was no evidence of fatigue crack growth on the stress corrosion cracks.  \n',
#   125.99555999999993,
#   614.54854,
#   473.29515600000013,
#   628.97626,
#   8,
#   3,
#   3],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The first DNV report concluded that the July 20 leak occurred at a colony of \n',
#   125.99555999999993,
#   590.97448,
#   465.352224,
#   605.4022,
#   8,
#   4,
#   0],
#  ['LTTextLineHorizontal',
#   'circumferentially oriented, outside-diameter, surface-breaking, interlinked stress corrosion \n',
#   125.9955599999999,
#   578.31454,
#   526.7501880000001,
#   592.74226,
#   8,
#   4,
#   1],
#  ['LTTextLineHorizontal',
#   'cracks located across the longitudinal seam weld, which had a 10 o\xe2\x80\x99clock orientation. \n',
#   125.99555999999993,
#   565.6546,
#   504.50800200000015,
#   580.08232,
#   8,
#   4,
#   2],
#  ['LTTextLineHorizontal',
#   'Coinciding with this colony were circumferentially oriented, inside-diameter, surface-\n',
#   125.99555999999995,
#   552.99466,
#   504.7144260000001,
#   567.42238,
#   8,
#   4,
#   3],
#  ['LTTextLineHorizontal',
#   'breaking cracks located at the seam weld. These inside-diameter cracks likely formed in the \n',
#   125.99555999999995,
#   540.33472,
#   532.5146879999998,
#   554.76244,
#   8,
#   4,
#   4],
#  ['LTTextLineHorizontal',
#   'pipe mill from the trimming tool and are referred to as trimming cracks. The stress corrosion \n',
#   125.99555999999995,
#   527.7406599999999,
#   536.196282,
#   542.16838,
#   8,
#   4,
#   5],
#  ['LTTextLineHorizontal',
#   'cracks propagated to one of these inside-diameter, surface-breaking cracks, resulting in the \n',
#   125.99555999999995,
#   515.0807199999999,
#   528.575064,
#   529.50844,
#   8,
#   4,
#   6],
#  ['LTTextLineHorizontal',
#   'leak. The maximum depth of the stress corrosion crack at the failure site was 3.73 mm (78 per \n',
#   125.99555999999995,
#   502.42077999999987,
#   542.6843639999998,
#   516.8485,
#   8,
#   4,
#   7],
#  ['LTTextLineHorizontal',
#   'cent of nominal wall thickness). Through-wall length of the crack was 36 mm. Other crack \n',
#   125.99555999999995,
#   489.76083999999986,
#   528.2829959999999,
#   504.1885599999999,
#   8,
#   4,
#   8],
#  ['LTTextLineHorizontal',
#   'colonies were present on the pipe near the 3 and 9 o\xe2\x80\x99clock positions. Pembina noted some \n',
#   125.99555999999993,
#   477.10089999999985,
#   523.953582,
#   491.5286199999999,
#   8,
#   4,
#   9],
#  ['LTTextLineHorizontal',
#   'minor external corrosion defects on the joint of the failed pipe.  \n',
#   125.99555999999993,
#   464.37507999999985,
#   407.4338220000001,
#   478.8027999999999,
#   8,
#   4,
#   10],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'The second DNV report concluded that the August 15 leak occurred at a colony of \n',
#   125.99555999999993,
#   440.8010199999999,
#   491.62516799999935,
#   455.2287399999999,
#   8,
#   5,
#   0],
#  ['LTTextLineHorizontal',
#   'circumferentially oriented, outside-diameter, surface-breaking, interlinked stress corrosion \n',
#   125.99555999999993,
#   428.20695999999987,
#   526.7501880000001,
#   442.6346799999999,
#   8,
#   5,
#   1],
#  ['LTTextLineHorizontal',
#   'cracks located near the longitudinal seam weld, which had a 2 o\xe2\x80\x99clock orientation. The stress \n',
#   125.99555999999993,
#   415.54701999999986,
#   537.499608,
#   429.9747399999999,
#   8,
#   5,
#   2],
#  ['LTTextLineHorizontal',
#   'corrosion cracks propagated nearly through wall, which lead to final failure by ductile \n',
#   125.99555999999995,
#   402.88707999999986,
#   507.291432,
#   417.3147999999999,
#   8,
#   5,
#   3],
#  ['LTTextLineHorizontal',
#   'overload. Inside-diameter, surface-breaking, mill-formed cracks that were present at the first \n',
#   125.99555999999993,
#   390.22713999999985,
#   535.904214,
#   404.65485999999987,
#   8,
#   5,
#   4],
#  ['LTTextLineHorizontal',
#   'failure were not present at the second failure. The maximum depth of the stress corrosion \n',
#   125.9955599999999,
#   377.56719999999984,
#   521.3260679999995,
#   391.99491999999987,
#   8,
#   5,
#   5],
#  ['LTTextLineHorizontal',
#   'crack at the failure site was 4.8 mm (100 per cent of nominal wall thickness). The length of \n',
#   125.9955599999999,
#   364.90725999999984,
#   530.4460559999999,
#   379.33497999999986,
#   8,
#   5,
#   6],
#  ['LTTextLineHorizontal',
#   'the crack that contained the failure was almost 70 mm. Several other crack colonies were \n',
#   125.99555999999987,
#   352.3131999999998,
#   520.5640559999995,
#   366.74091999999985,
#   8,
#   5,
#   7],
#  ['LTTextLineHorizontal',
#   'present on the pipe joint. Most of the colonies were located between the 1:30 and 2:30 \n',
#   125.99555999999987,
#   339.6532599999998,
#   508.2027720000002,
#   354.08097999999984,
#   8,
#   5,
#   8],
#  ['LTTextLineHorizontal',
#   'o\xe2\x80\x99clock positions, with one colony located at about the 9:40 o\xe2\x80\x99clock position.  \n',
#   125.99555999999987,
#   326.9274399999998,
#   471.02888399999983,
#   341.35515999999984,
#   8,
#   5,
#   9],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Since the DNV reports concluded that the failure mechanism was the same in both failures \n',
#   125.9955599999999,
#   303.35337999999985,
#   527.7054479999999,
#   317.78109999999987,
#   8,
#   6,
#   0],
#  ['LTTextLineHorizontal',
#   'and since Pembina has decided to replace the segment of pipeline containing the failed \n',
#   125.9955599999999,
#   290.69343999999984,
#   510.18026999999984,
#   305.12115999999986,
#   8,
#   6,
#   1],
#  ['LTTextLineHorizontal',
#   'sections, Pembina did not perform a detailed root cause analysis for the second failure.  \n',
#   125.99555999999993,
#   277.96761999999984,
#   513.0186000000001,
#   292.39533999999986,
#   8,
#   6,
#   2],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '                                                      \n',
#   71.99591999999993,
#   232.3681,
#   219.0,
#   248.1361,
#   8,
#   7,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   '6  According to Stress Corrosion Cracking, Recommended Practices, 2nd Edition, published by the Canadian Energy \n',
#   72.0,
#   210.11568,
#   540.1938000000001,
#   223.99872,
#   8,
#   8,
#   0],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTAnno'],
#  ['-', '\n'],
#  ['LTTextBoxHorizontal'],
#  ['LTTextLineHorizontal',
#   'Pipeline Association (CEPA Recommended Practices), transgranular stress corrosion cracking (SCC) on buried, \n',
#   80.64654000000002,
#   198.65279999999998,
#   531.65175,
#   211.9794,
#   8,
#   9,
#   0],
#  ['LTTextLineHorizontal',
#   'high-pressure commodity pipelines occurs as a result of the interaction of susceptible metallic material, tensile \n',
#   80.64654000000004,
#   187.1298,
#   525.0034799999994,
#   200.29608,
#   8,
#   9,
#   1],
#  ['LTTextLineHorizontal',
#   'stress, and an aggressive electrolyte. SCC initiates on the external pipeline surface and grows in both depth and \n',
#   80.64654000000004,
#   175.66691999999998,
#   528.384228,
#   188.83319999999998,
#   8,
#   9,
#   2],
#  ['LTTextLineHorizontal',
#   'surface directions. Growth along the surface is perpendicular to the principal stress, typically the hoop stress, \n',
#   80.64654000000002,
#   164.14391999999998,
#   519.1848659999999,
#   177.31019999999998,
#   8,
#   9,
#   3],
#  ['LTTextLineHorizontal',
#   'resulting in crack alignment along the longitudinal axis of the pipeline (axially aligned SCC). Occasionally \n',
#   80.64653999999999,
#   152.62091999999998,
#   511.16485800000004,
#   165.78719999999998,
#   8,
#   9,
#   4],
#  ['LTTextLineHorizontal',
#   'complex stresses occur, which may alter the direction of propagation from the longitudinal axis. SCC occurs \n',
#   80.65656000000001,
#   141.15804,
#   517.3552140000005,
#   154.32432,
#   8,
#   9,
#   5],
#  ['LTTextLineHorizontal',
#   'beneath a mechanically failed coating and is capable of forming in the absence of general corrosion. \n',
#   80.65656000000001,
#   129.63504,
#   483.6459299999999,
#   142.80132,
#   8,
#   9,
#   6],
#  ['LTTextLineHorizontal',
#   'Circumferentially oriented SCC (C-SCC) is a subset of transgranular SCC where the principle stress acting on the \n',
#   80.65655999999998,
#   118.11204000000001,
#   538.7208600000001,
#   131.27832,
#   8,
#   9,
#   7],
#  ['LTTextLineHorizontal',
#   'crack is a bending stress, which is typically acting in a longitudinal direction. The bending stress may be due to \n',
#   80.65655999999996,
#   106.64916000000001,
#   528.4653899999996,
#   119.81544000000001,
#   8,
#   9,
#   8],
#  ['LTTextLineHorizontal',
#   'differential settlement of the backfill beneath the pipe, geotechnical ground movement, or possibly external loads \n',
#   80.65655999999996,
#   95.12616000000001,
#   536.4062399999995,
#   108.29244000000001,
#   8,
#   9,
#   9],
#  ['LTTextLineHorizontal',
#   'other than soil. \n',
#   80.65655999999996,
#   83.60316000000002,
#   142.89879599999998,
#   96.76944000000002,
#   8,
#   9,
#   10],
#  ['LTAnno'],
#  ['-', '\n'],
#  ...]

# %%
tree
