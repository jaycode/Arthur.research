# %%
paragraph = """The ruptured pipeline section8
consisted of four pipe segments buried to a depth of about
3 feet 9 inches.9
Two of the 18-inch-diameter ruptured pipe segments were part of the original
1959 installation with a spiral-wrapped, field-applied Polyken 900 general utility polyethylene
tape as the primary means of corrosion protection. These two polyethylene-tape–coated pipe
segments were manufactured to the American Petroleum Institute (API) Standard 5LX10 grade
X5211 with a 0.25-inch nominal wall thickness and a direct current electric resistance
welded (ERW) longitudinal weld seam. Samples from the pipe material were tested, and the
results showed that the mechanical and chemical properties of these pipe segments met the
requirements of the API standard."""

# %%
import nltk, re, pprint
def ie_preprocess(document):
    pprint.pprint(document)
    sentences = nltk.sent_tokenize(document)
    pprint.pprint(sentences)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    pprint.pprint(sentences)
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    return sentences

sentences = ie_preprocess(paragraph)
pprint.pprint(sentences)
# Out:
# 'The ruptured pipeline section8\nconsisted of four pipe segments buried to a depth of about\n3 feet 9 inches.9\nTwo of the 18-inch-diameter ruptured pipe segments were part of the original\n1959 installation with a spiral-wrapped, field-applied Polyken 900 general utility polyethylene\ntape as the primary means of corrosion protection. These two polyethylene-tape\xe2\x80\x93coated pipe\nsegments were manufactured to the American Petroleum Institute (API) Standard 5LX10 grade\nX5211 with a 0.25-inch nominal wall thickness and a direct current electric resistance\nwelded (ERW) longitudinal weld seam. Samples from the pipe material were tested, and the\nresults showed that the mechanical and chemical properties of these pipe segments met the\nrequirements of the API standard.'
# ['The ruptured pipeline section8\nconsisted of four pipe segments buried to a depth of about\n3 feet 9 inches.9\nTwo of the 18-inch-diameter ruptured pipe segments were part of the original\n1959 installation with a spiral-wrapped, field-applied Polyken 900 general utility polyethylene\ntape as the primary means of corrosion protection.',
#  'These two polyethylene-tape\xe2\x80\x93coated pipe\nsegments were manufactured to the American Petroleum Institute (API) Standard 5LX10 grade\nX5211 with a 0.25-inch nominal wall thickness and a direct current electric resistance\nwelded (ERW) longitudinal weld seam.',
#  'Samples from the pipe material were tested, and the\nresults showed that the mechanical and chemical properties of these pipe segments met the\nrequirements of the API standard.']
# [['The',
#   'ruptured',
#   'pipeline',
#   'section8',
#   'consisted',
#   'of',
#   'four',
#   'pipe',
#   'segments',
#   'buried',
#   'to',
#   'a',
#   'depth',
#   'of',
#   'about',
#   '3',
#   'feet',
#   '9',
#   'inches.9',
#   'Two',
#   'of',
#   'the',
#   '18-inch-diameter',
#   'ruptured',
#   'pipe',
#   'segments',
#   'were',
#   'part',
#   'of',
#   'the',
#   'original',
#   '1959',
#   'installation',
#   'with',
#   'a',
#   'spiral-wrapped',
#   ',',
#   'field-applied',
#   'Polyken',
#   '900',
#   'general',
#   'utility',
#   'polyethylene',
#   'tape',
#   'as',
#   'the',
#   'primary',
#   'means',
#   'of',
#   'corrosion',
#   'protection',
#   '.'],
#  ['These',
#   'two',
#   'polyethylene-tape\xe2\x80\x93coated',
#   'pipe',
#   'segments',
#   'were',
#   'manufactured',
#   'to',
#   'the',
#   'American',
#   'Petroleum',
#   'Institute',
#   '(',
#   'API',
#   ')',
#   'Standard',
#   '5LX10',
#   'grade',
#   'X5211',
#   'with',
#   'a',
#   '0.25-inch',
#   'nominal',
#   'wall',
#   'thickness',
#   'and',
#   'a',
#   'direct',
#   'current',
#   'electric',
#   'resistance',
#   'welded',
#   '(',
#   'ERW',
#   ')',
#   'longitudinal',
#   'weld',
#   'seam',
#   '.'],
#  ['Samples',
#   'from',
#   'the',
#   'pipe',
#   'material',
#   'were',
#   'tested',
#   ',',
#   'and',
#   'the',
#   'results',
#   'showed',
#   'that',
#   'the',
#   'mechanical',
#   'and',
#   'chemical',
#   'properties',
#   'of',
#   'these',
#   'pipe',
#   'segments',
#   'met',
#   'the',
#   'requirements',
#   'of',
#   'the',
#   'API',
#   'standard',
#   '.']]
# [[('The', 'DT'),
#   ('ruptured', 'JJ'),
#   ('pipeline', 'NN'),
#   ('section8', 'NN'),
#   ('consisted', 'VBD'),
#   ('of', 'IN'),
#   ('four', 'CD'),
#   ('pipe', 'NN'),
#   ('segments', 'NNS'),
#   ('buried', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('depth', 'NN'),
#   ('of', 'IN'),
#   ('about', 'IN'),
#   ('3', 'CD'),
#   ('feet', 'NNS'),
#   ('9', 'CD'),
#   ('inches.9', 'JJ'),
#   ('Two', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('18-inch-diameter', 'JJ'),
#   ('ruptured', 'JJ'),
#   ('pipe', 'NN'),
#   ('segments', 'NNS'),
#   ('were', 'VBD'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('original', 'JJ'),
#   ('1959', 'CD'),
#   ('installation', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('spiral-wrapped', 'JJ'),
#   (',', ','),
#   ('field-applied', 'JJ'),
#   ('Polyken', 'NNP'),
#   ('900', 'CD'),
#   ('general', 'JJ'),
#   ('utility', 'NN'),
#   ('polyethylene', 'NN'),
#   ('tape', 'NN'),
#   ('as', 'IN'),
#   ('the', 'DT'),
#   ('primary', 'JJ'),
#   ('means', 'NNS'),
#   ('of', 'IN'),
#   ('corrosion', 'NN'),
#   ('protection', 'NN'),
#   ('.', '.')],
#  [('These', 'DT'),
#   ('two', 'CD'),
#   ('polyethylene-tape\xe2\x80\x93coated', 'JJ'),
#   ('pipe', 'NN'),
#   ('segments', 'NNS'),
#   ('were', 'VBD'),
#   ('manufactured', 'VBN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('American', 'NNP'),
#   ('Petroleum', 'NNP'),
#   ('Institute', 'NNP'),
#   ('(', '('),
#   ('API', 'NNP'),
#   (')', ')'),
#   ('Standard', 'NNP'),
#   ('5LX10', 'CD'),
#   ('grade', 'NN'),
#   ('X5211', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('0.25-inch', 'JJ'),
#   ('nominal', 'JJ'),
#   ('wall', 'NN'),
#   ('thickness', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('direct', 'JJ'),
#   ('current', 'JJ'),
#   ('electric', 'JJ'),
#   ('resistance', 'NN'),
#   ('welded', 'VBD'),
#   ('(', '('),
#   ('ERW', 'NNP'),
#   (')', ')'),
#   ('longitudinal', 'JJ'),
#   ('weld', 'NN'),
#   ('seam', 'NN'),
#   ('.', '.')],
#  [('Samples', 'NNS'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('pipe', 'JJ'),
#   ('material', 'NN'),
#   ('were', 'VBD'),
#   ('tested', 'VBN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('results', 'NNS'),
#   ('showed', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('mechanical', 'JJ'),
#   ('and', 'CC'),
#   ('chemical', 'JJ'),
#   ('properties', 'NNS'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('pipe', 'JJ'),
#   ('segments', 'NNS'),
#   ('met', 'VBD'),
#   ('the', 'DT'),
#   ('requirements', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('API', 'NNP'),
#   ('standard', 'NN'),
#   ('.', '.')]]

# %%
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"), 
            ("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]

grammar = "NP: {<DT>?<JJ>*<NN>}"

cp = nltk.RegexpParser(grammar)
result = cp.parse(sentence)
print(result)
# result.draw # not working in ipython.

# Not working either.
# --------------------------
# from nltk import Tree
# from nltk.draw.util import CanvasFrame
# from nltk.draw.tree import TreeWidget
# cf = CanvasFrame()
# t = Tree.fromstring(result)
# tc = TreeWidget(cf.canvas(),t)
# cf.add_widget(tc,10,10) # (10,10) offsets
# cf.print_to_file('tree.ps')
# cf.destroy()
# Out:
# (S
#   (NP the/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat/NN))
